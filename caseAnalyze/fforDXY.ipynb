# %%
import pandas as pd

# %%
csv_data = pd.read_csv("../data/DXYArea.csv")

# %%
#add a new line named date
csv_data["updateTime"]  = pd.to_datetime(csv_data["updateTime"],format='%Y-%m-%d %H:%M:%S')
csv_data["date"] = csv_data["updateTime"].dt.date

# %%
csv_data.head(6)
# Out:
#   continentName continentEnglishName countryName countryEnglishName  \
# 0            非洲               Africa         索马里             Somali
# 1            欧洲               Europe         奥地利            Austria
# 2            欧洲               Europe          瑞典             Sweden
# 3            亚洲                 Asia        巴基斯坦           Pakistan
# 4            欧洲               Europe        克罗地亚            Croatia
# 5            亚洲                 Asia        亚美尼亚            Armenia
#
#   provinceName provinceEnglishName  province_zipCode  province_confirmedCount  \
# 0          索马里              Somali            985008                        7
# 1          奥地利             Austria            963001                    11383
# 2           瑞典              Sweden            962005                     6078
# 3         巴基斯坦            Pakistan            953006                     2458
# 4         克罗地亚             Croatia            965005                     1079
# 5         亚美尼亚             Armenia            955002                      736
#
#    province_suspectedCount  province_curedCount  province_deadCount  \
# 0                      0.0                    1                   0
# 1                      0.0                 2022                 168
# 2                      0.0                   17                 333
# 3                      0.0                  107                  35
# 4                      0.0                   88                   8
# 5                      0.0                   43                   7
#
#            updateTime cityName cityEnglishName  city_zipCode  \
# 0 2020-04-04 11:36:59      NaN             NaN           NaN
# 1 2020-04-04 11:27:53      NaN             NaN           NaN
# 2 2020-04-04 11:27:53      NaN             NaN           NaN
# 3 2020-04-04 11:27:53      NaN             NaN           NaN
# 4 2020-04-04 11:27:53      NaN             NaN           NaN
# 5 2020-04-04 11:27:53      NaN             NaN           NaN
#
#    city_confirmedCount  city_suspectedCount  city_curedCount  city_deadCount  \
# 0                  NaN                  NaN              NaN             NaN
# 1                  NaN                  NaN              NaN             NaN
# 2                  NaN                  NaN              NaN             NaN
# 3                  NaN                  NaN              NaN             NaN
# 4                  NaN                  NaN              NaN             NaN
# 5                  NaN                  NaN              NaN             NaN
#
#          date
# 0  2020-04-04
# 1  2020-04-04
# 2  2020-04-04
# 3  2020-04-04
# 4  2020-04-04
# 5  2020-04-04

# %%
#groupby
dateGroupDate = csv_data.groupby("date")
# for n, g in dateGroupDate:
#     print("multiGroup on:", n, "\n|",g ,"|")

# %%
csv_global_comfirmed = pd.read_csv("../data/time_series_covid19_confirmed_global.csv")
csv_global_dead = pd.read_csv("../data/time_series_covid19_deaths_global.csv")
csv_global_recovered = pd.read_csv("../data/time_series_covid19_recovered_global.csv")

csv_global_dead.head(6)
# Out:
#   Province/State       Country/Region      Lat     Long  1/22/20  1/23/20  \
# 0            NaN          Afghanistan  33.0000  65.0000        0        0
# 1            NaN              Albania  41.1533  20.1683        0        0
# 2            NaN              Algeria  28.0339   1.6596        0        0
# 3            NaN              Andorra  42.5063   1.5218        0        0
# 4            NaN               Angola -11.2027  17.8739        0        0
# 5            NaN  Antigua and Barbuda  17.0608 -61.7964        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  3/26/20  3/27/20  3/28/20  \
# 0        0        0        0        0  ...        4        4        4
# 1        0        0        0        0  ...        6        8       10
# 2        0        0        0        0  ...       25       26       29
# 3        0        0        0        0  ...        3        3        3
# 4        0        0        0        0  ...        0        0        0
# 5        0        0        0        0  ...        0        0        0
#
#    3/29/20  3/30/20  3/31/20  4/1/20  4/2/20  4/3/20  4/4/20
# 0        4        4        4       4       6       6       7
# 1       10       11       15      15      16      17      20
# 2       31       35       44      58      86     105     130
# 3        6        8       12      14      15      16      17
# 4        2        2        2       2       2       2       2
# 5        0        0        0       0       0       0       0
#
# [6 rows x 78 columns]

# %%
csv_China_comfirmed = csv_global_comfirmed[csv_global_comfirmed["Country/Region"] =="China"]
csv_China_dead = csv_global_dead[csv_global_dead["Country/Region"] =="China"]
csv_China_recovered = csv_global_recovered[csv_global_recovered["Country/Region"] =="China"]

# %%
date_columns = csv_global_comfirmed.columns.values[4:]
sum_confirmed_of_date = []
sum_dead_of_date = []
sum_recovered_of_date = []
sum_China_comfirmed = []
sum_China_dead = []
sum_China_recovered=[]
for cur_date in date_columns:
    sum_confirmed_of_date.append(csv_global_comfirmed[cur_date].sum())
    sum_dead_of_date.append(csv_global_dead[cur_date].sum())
    sum_recovered_of_date.append(csv_global_recovered[cur_date].sum())
    sum_China_comfirmed.append(csv_China_comfirmed[cur_date].sum())
    sum_China_dead.append(csv_China_dead[cur_date].sum())
    sum_China_recovered.append(csv_China_recovered[cur_date].sum())

# %%
# create new dataframe
global_data = {
    "date":date_columns,
    "confirmed_cases_global":sum_confirmed_of_date,
    "dead_cases_global":sum_dead_of_date,
    "recovered_cases_global":sum_recovered_of_date,
    "confirmed_cases_China":sum_China_comfirmed,
    "dead_cases_China":sum_China_dead,
    "recovered_cases_China":sum_China_recovered
}

df_global_data = pd.DataFrame(global_data)
df_global_data
# Out:
#        date  confirmed_cases_global  dead_cases_global  \
# 0   1/22/20                     555                 17
# 1   1/23/20                     654                 18
# 2   1/24/20                     941                 26
# 3   1/25/20                    1434                 42
# 4   1/26/20                    2118                 56
# ..      ...                     ...                ...
# 68  3/30/20                  782365              37582
# 69  3/31/20                  857487              42107
# 70   4/1/20                  932605              46809
# 71   4/2/20                 1013157              52983
# 72   4/3/20                 1095917              58787
#
#     recovered_cases_global  confirmed_cases_China  dead_cases_China  \
# 0                       28                    548                17
# 1                       30                    643                18
# 2                       36                    920                26
# 3                       39                   1406                42
# 4                       52                   2075                56
# ..                     ...                    ...               ...
# 68                  164566                  82198              3308
# 69                  178034                  82279              3309
# 70                  193177                  82361              3316
# 71                  210263                  82432              3322
# 72                  225796                  82511              3326
#
#     recovered_cases_China
# 0                      28
# 1                      30
# 2                      36
# 3                      39
# 4                      49
# ..                    ...
# 68                  75923
# 69                  76206
# 70                  76405
# 71                  76565
# 72                  76760
#
# [73 rows x 7 columns]

# %%
# df_global_data["lethal_rate_global"] = df_global_data["dead_cases_global"]/df_global_data["confirmed_cases_global"]
# df_global_data["cure_rate_global"] = df_global_data["recovered_cases_global"]/df_global_data["confirmed_cases_global"]
# df_global_data["lethal_rate_China"] = df_global_data["dead_cases_China"]/df_global_data["confirmed_cases_China"]
# df_global_data["cure_rate_China"] = df_global_data["recovered_cases_global"]/df_global_data["confirmed_cases_global"]

# %%
df_global_data_diff = df_global_data.set_index('date').diff()
df_global_data_diff
# df_global_data_diff = df_global_data_diff.reset_index(drop=True)

df_global_data_diff = df_global_data_diff[df_global_data_diff.index !="1/22/20"]

df_global_data_diff
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-11bbd5527fd8> in <module>
#       6
#       7 df_global_data_diff
# ----> 8 score = model.score(x_test,y_test)
#       9
#
# NameError: name 'model' is not defined

# %%
df_global_data.to_csv("../data/case_by_date.csv")

# %%
df_global_data_diff.to_csv("../data/increase_case_by_date.csv")

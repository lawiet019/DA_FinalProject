# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
# read the data of increae case
case_by_date_data= pd.read_csv("../data/increase_case_by_date.csv")
#read the data of stock index
stock_by_date_data = pd.DataFrame( pd.read_csv("../data/stock_shanghai.csv"),columns=["date","close","volume"])
#convert the format of
case_by_date_data["date"] ="0"+ case_by_date_data["date"]+"20"
case_by_date_data["date"]
# Out:
# 0     01/23/2020
# 1     01/24/2020
# 2     01/25/2020
# 3     01/26/2020
# 4     01/27/2020
#          ...
# 67    03/30/2020
# 68    03/31/2020
# 69     04/1/2020
# 70     04/2/2020
# 71     04/3/2020
# Name: date, Length: 72, dtype: object

# %%
# get the  increase of the data 
for i in range(0,len(stock_by_date_data)):
    if i == 0:
        stock_by_date_data['increase'][i] = 'null'
    else:
        stock_by_date_data['increase'][i] = format((stock_by_date_data['close'][i] - stock_by_date_data['close'][i-1])/stock_by_date_data['close'][i-1],'.2%')

# %%
# summary the stock price
case_by_date_data.describe()
stock_by_date_data.describe()
stock_by_date_data
# Out:
#           date      close       volume
# 0   2020-02-03  2746.6050  21591210240
# 1   2020-02-04  2783.2870  36404620032
# 2   2020-02-05  2818.0870  30976182272
# 3   2020-02-06  2866.5090  31639214336
# 4   2020-02-07  2875.9630  30947964160
# 5   2020-02-10  2890.4870  29492978432
# 6   2020-02-11  2901.6740  26916833536
# 7   2020-02-12  2926.8990  24873342976
# 8   2020-02-13  2906.0730  27480484352
# 9   2020-02-14  2917.0070  25065062656
# 10  2020-02-17  2983.6220  31319800832
# 11  2020-02-18  2984.9710  31166591232
# 12  2020-02-19  2975.4010  31514115072
# 13  2020-02-20  3030.1540  34573288192
# 14  2020-02-21  3039.6690  36455727616
# 15  2020-02-24  3031.2330  37043004416
# 16  2020-02-25  3013.0500  44162276096
# 17  2020-02-26  2987.9280  46904955136
# 18  2020-02-27  2991.3280  35052365824
# 19  2020-02-28  2880.3030  40121691392
# 20  2020-03-02  2970.9310  36733336832
# 21  2020-03-03  2992.8960  41010804736
# 22  2020-03-04  3011.6650  35333827840
# 23  2020-03-05  3071.6770  44542580736
# 24  2020-03-06  3034.5110  36206153216
# 25  2020-03-09  2943.2907  41456073600
# 26  2020-03-10  2996.7618  39329664800
# 27  2020-03-11  2968.5174  35247097000
# 28  2020-03-12  2923.4856  30777845700
# 29  2020-03-13  2887.4265  36645043600
# 30  2020-03-16  2789.2537  35187866500
# 31  2020-03-17  2779.6407  30614967700
# 32  2020-03-18  2729.6185  28763249300
# 33  2020-03-19  2702.1296  30230274700
# 34  2020-03-20  2745.6182  25201950700
# 35  2020-03-23  2660.1674  24982025000
# 36  2020-03-24  2722.4381  25702193000
# 37  2020-03-25  2781.5913  27314446600
# 38  2020-03-26  2764.9109  23408402200
# 39  2020-03-27  2772.2033  24076406600
# 40  2020-03-30  2747.2138  23970660400
# 41  2020-03-31  2750.2962  21859867400
# 42  2020-04-01  2734.5215  21725342700
# 43  2020-04-02  2780.6379  21786460000
# 44  2020-04-03  2763.9874  20083740400
# 45  2020-04-07  2820.7634  27019818600
# 46  2020-04-08  2815.3686  24351530500
# 47  2020-04-09  2825.9036  23818484300
# 48  2020-04-10  2796.6312  23345476800

# %%
# convert to datetime
stock_by_date_data["date"] = pd.to_datetime(stock_by_date_data["date"],format="%Y-%m-%d")
case_by_date_data["date"] = pd.to_datetime(case_by_date_data["date"],format="%m/%d/%Y")

# %%
case_by_date_data
# Out:
#          date  confirmed_cases_global  dead_cases_global  \
# 0  2020-01-23                    99.0                1.0
# 1  2020-01-24                   287.0                8.0
# 2  2020-01-25                   493.0               16.0
# 3  2020-01-26                   684.0               14.0
# 4  2020-01-27                   809.0               26.0
# ..        ...                     ...                ...
# 67 2020-03-30                 62248.0             3657.0
# 68 2020-03-31                 75122.0             4525.0
# 69 2020-04-01                 75118.0             4702.0
# 70 2020-04-02                 80552.0             6174.0
# 71 2020-04-03                 82760.0             5804.0
#
#     recovered_cases_global  confirmed_cases_China  dead_cases_China  \
# 0                      2.0                   95.0               1.0
# 1                      6.0                  277.0               8.0
# 2                      3.0                  486.0              16.0
# 3                     13.0                  669.0              14.0
# 4                      9.0                  802.0              26.0
# ..                     ...                    ...               ...
# 67                 15484.0                   76.0               4.0
# 68                 13468.0                   81.0               1.0
# 69                 15143.0                   82.0               7.0
# 70                 17086.0                   71.0               6.0
# 71                 15533.0                   79.0               4.0
#
#     recovered_cases_China
# 0                     2.0
# 1                     6.0
# 2                     3.0
# 3                    10.0
# 4                     9.0
# ..                    ...
# 67                  341.0
# 68                  283.0
# 69                  199.0
# 70                  160.0
# 71                  195.0
#
# [72 rows x 7 columns]

# %%
# create a new table 
merged_data = pd.merge(stock_by_date_data,case_by_date_data,on="date")
# normalize the data
merged_data_norm=merged_data.apply(lambda x: (x - np.min(x)) / (np.max(x) - np.min(x)))
plt.savefig("boxplot.jpg")
fig = plt.figure(figsize=(20,4)) 
merged_data_norm.iloc[:,1:].boxplot()
merged_data_norm["close"] = merged_data["close"]
 
# plt.figure(num=None, figsize=(100, 600), dpi=1, facecolor='w', edgecolor='k')
plt.savefig("boxplot.jpg")
plt.title('boxplot of the normalization of stock data in shanghai and covid-19 cases in china and world',fontsize='large',fontweight='bold')
plt.show()
merged_data_norm.corr()
# Out:
#                             date     close    volume  confirmed_cases_global  \
# date                    1.000000 -0.485193 -0.313550                0.795672
# close                  -0.485193  1.000000  0.711772               -0.687698
# volume                 -0.313550  0.711772  1.000000               -0.681152
# confirmed_cases_global  0.795672 -0.687698 -0.681152                1.000000
# dead_cases_global       0.767249 -0.611243 -0.646905                0.978170
# recovered_cases_global  0.734284 -0.439898 -0.510605                0.897350
# confirmed_cases_China  -0.526100  0.030356 -0.144543               -0.195344
# dead_cases_China       -0.680662  0.391813  0.098782               -0.447087
# recovered_cases_China  -0.217492  0.724114  0.739937               -0.565912
#
#                         dead_cases_global  recovered_cases_global  \
# date                             0.767249                0.734284
# close                           -0.611243               -0.439898
# volume                          -0.646905               -0.510605
# confirmed_cases_global           0.978170                0.897350
# dead_cases_global                1.000000                0.938303
# recovered_cases_global           0.938303                1.000000
# confirmed_cases_China           -0.234886               -0.265291
# dead_cases_China                -0.434747               -0.394357
# recovered_cases_China           -0.526819               -0.336922
#
#                         confirmed_cases_China  dead_cases_China  \
# date                                -0.526100         -0.680662
# close                                0.030356          0.391813
# volume                              -0.144543          0.098782
# confirmed_cases_global              -0.195344         -0.447087
# dead_cases_global                   -0.234886         -0.434747
# recovered_cases_global              -0.265291         -0.394357
# confirmed_cases_China                1.000000          0.765385
# dead_cases_China                     0.765385          1.000000
# recovered_cases_China               -0.100039          0.247086
#
#                         recovered_cases_China
# date                                -0.217492
# close                                0.724114
# volume                               0.739937
# confirmed_cases_global              -0.565912
# dead_cases_global                   -0.526819
# recovered_cases_global              -0.336922
# confirmed_cases_China               -0.100039
# dead_cases_China                     0.247086
# recovered_cases_China                1.000000

# %%
merged_data_norm.iloc[:,1:]
# Out:
#         close    volume  confirmed_cases_global  dead_cases_global  \
# 0   2746.6050  0.056204                0.032487           0.009724
# 1   2783.2870  0.608506                0.043623           0.010049
# 2   2818.0870  0.406113                0.040369           0.011021
# 3   2866.5090  0.430833                0.033276           0.010697
# 4   2875.9630  0.405061                0.038596           0.013128
# 5   2890.4870  0.350813                0.026633           0.016694
# 6   2901.6740  0.254764                0.019686           0.015559
# 7   2926.8990  0.178575                0.000000           0.000162
# 8   2906.0730  0.275780                0.178866           0.040357
# 9   2917.0070  0.185723                0.074058           0.023987
# 10  2983.6220  0.418924                0.019614           0.015235
# 11  2984.9710  0.413212                0.017719           0.021880
# 12  2975.4010  0.426169                0.001020           0.017990
# 13  3030.1540  0.540227                0.001688           0.019611
# 14  3039.6690  0.610412                0.002465           0.000000
# 15  3031.2330  0.632308                0.002235           0.025284
# 16  3013.0500  0.897742                0.005174           0.012156
# 17  2987.9280  1.000000                0.006837           0.009400
# 18  2991.3280  0.558089                0.011404           0.006483
# 19  2880.3030  0.747093                0.011501           0.008752
# 20  2970.9310  0.620762                0.018436           0.013776
# 21  2992.8960  0.780243                0.025686           0.011507
# 22  3011.6650  0.568583                0.022601           0.014587
# 23  3071.6770  0.911921                0.028503           0.014587
# 24  3034.5110  0.601107                0.042458           0.017504
# 25  2943.2907  0.796844                0.040684           0.029498
# 26  2996.7618  0.717563                0.055999           0.043760
# 27  2968.5174  0.565349                0.083021           0.056564
# 28  2923.4856  0.398718                0.024994           0.016370
# 29  2887.4265  0.617470                0.199585           0.110211
# 16               0.772783
# 17               0.694889
# 18               0.829741
# 19               1.000000
# 20               0.782328
# 21               0.752771
# 22               0.738916
# 23               0.658867
# 24               0.462131
# 25               0.389470
# 26               0.377463
# 27               0.403941
# 28               0.340517
# 29               0.352217
# 30               0.228448
# 31               0.226909
# 32               0.248153
# 33               0.193658
# 34               0.178571
# 35               0.092672
# 36               0.096983
# 37               0.105296
# 38               0.079126
# 39               0.119458
# 40               0.058498
# 41               0.040640
# 42               0.014778
# 43               0.002771
# 44               0.013547

# %%
sns.pairplot(merged_data_norm, x_vars=['confirmed_cases_global','dead_cases_global','recovered_cases_global','confirmed_cases_China','dead_cases_China','recovered_cases_China'], y_vars='close', height=7, aspect=0.8,kind = 'reg')
plt.savefig("scatter plot.jpg")

# %%
# Out:
#     confirmed_cases_global  dead_cases_global  recovered_cases_global  \
# 36                 39810.0             2120.0                  9649.0
# 37                 49608.0             2556.0                  5787.0
# 38                 61938.0             2789.0                  8363.0
# 39                 63700.0             3228.0                  8765.0
# 40                 62248.0             3657.0                 15484.0
# 41                 75122.0             4525.0                 13468.0
# 42                 75118.0             4702.0                 15143.0
# 43                 80552.0             6174.0                 17086.0
# 44                 82760.0             5804.0                 15533.0
#
#     confirmed_cases_China  dead_cases_China  recovered_cases_China
# 36                   93.0               7.0                  466.0
# 37                   70.0               4.0                  493.0
# 38                  121.0               6.0                  408.0
# 39                  115.0               5.0                  539.0
# 40                   76.0               4.0                  341.0
# 41                   81.0               1.0                  283.0
# 42                   82.0               7.0                  199.0
# 43                   71.0               6.0                  160.0
# 44                   79.0               4.0                  195.0

# %%
# time series analysis
#get the len of data
len_rows = merged_data.shape[0]
# use 0.9 as train and 0.1 as test
split_point = int(len_rows * 0.8)
y_train = merged_data_norm.iloc[:split_point,[1]]
x_train = merged_data_norm.iloc[:split_point,3:]
y_test = merged_data_norm.iloc[split_point:,[1]]
x_test = merged_data_norm.iloc[split_point:,3:]

# %%
linreg = LinearRegression()
 
model= linreg.fit(x_train,y_train)
 
a  = linreg.intercept_#intercept
 
b = linreg.coef_#Regression coefficients

b
# Out:
# array([[  154.38426268, -1124.7251844 ,    18.00690626,  -193.67388538,
#           119.48326589,   145.61666485]])

# %%
# validation
y_pred = linreg.predict(x_test)
y_pred
# Out:
# array([[2598.30681325],
#        [2533.1754351 ],
#        [2513.04350354],
#        [2442.22534698],
#        [2359.59346715],
#        [2219.27393161],
#        [2187.84832614],
#        [1929.69106127],
#        [2000.14510587]])

# %%
merged_data_norm["date"] = merged_data["date"]

# %%
merged_data_norm["date"] = merged_data["date"]

# %%
merged_data_norm.set_index("date",inplace=True)
fig = plt.figure(figsize=(20,4)) 
plt.plot(merged_data_norm["close"])
plt.plot(merged_data_norm["confirmed_cases_China"])
plt.plot(merged_data_norm["confirmed_cases_global"])
